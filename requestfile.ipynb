# %%
import requests as req

# %%
url = 'https://ndl.iitkgp.ac.in/'

# %%
resp = req.get(url)
resp
# Out:
# <Response [200]>

# %%
cont =resp.content.decode('utf-8')

print(cont)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
# 	<meta charset="utf-8">
# 	<title>National Digital Library of India (NDLI)</title>
# 	<meta name="title" content="National Digital Library of India (NDLI)">
# 	<meta name="description" content="National Digital Library of India (NDLI) is a virtual repository of learning resources which is not just a repository with search/browse facilities but provides a host of services for the learner community. It is sponsored and mentored by Ministry of Education, Government of India, through its National Mission on Education through Information and Communication Technology (NMEICT).">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<link rel="preconnect" href="https://fonts.googleapis.com">
# 	<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# 	<link rel="stylesheet" type="text/css" href="/libs/bootstrap-5.3.3-dist/css/bootstrap.min.css"/>
# ...

# %%
type(resp.headers)

head = resp.headers

print(head)
# Out:
# {'Server': 'nginx', 'Date': 'Mon, 27 May 2024 11:56:24 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'lumos=1716810984_22465_1; expires=Wed, 26 Jun 2024 11:56:24 GMT; Max-Age=2592000; path=/', 'Content-Encoding': 'gzip'}

# %%
print(f'Content-Type = {head["Content-Type"]}')

print(f'Date = {head["Date"]}')
# Out:
# Content-Type = text/html; charset=UTF-8
# Date = Mon, 27 May 2024 11:56:24 GMT

# %%
useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'

# %%
checkHeader = req.get(url, headers= {'User-Agent' : useragent})
checkHeader
# Out:
# <Response [200]>

# %%
checkHeader.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
