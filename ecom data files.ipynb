# %% [markdown]
# #   Ecommerce Sales data with only 50 rows

# %%
import pandas as pd
import numpy as np

# %%
cust1 = pd.DataFrame([{ 
                'cust_id': 'cust_id-CG-12520',
                'customer_name': 'Claire Gute',
                'segment': 'Consumer',
                'age': 67,
                'country': 'United States',
                'city': 'Henderson',
                'state': 'Kentucky',
                'postal_code': 42420,
                'region': 'South'


},
{
        'cust_id': 'cust_id-DV-13045',
        'customer_name': 'Darrin Van Huff',
        'segment': 'Corporate',
        'age': 31,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90036,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-SO-20335',
        'customer_name': 'Sean O\'Donnell',
        'segment': 'Consumer',
        'age': 65,
        'country': 'United States',
        'city': 'Fort Lauderdale',
        'state': 'Florida',
        'postal_code': 33311,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-BH-11710',
        'customer_name': 'Brosina Hoffman',
        'segment': 'Consumer',
        'age': 20,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90032,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-AA-10480',
        'customer_name': 'Andrew Allen',
        'segment': 'Consumer',
        'age': 50,
        'country': 'United States',
        'city': 'Concord',
        'state': 'North Carolina',
        'postal_code': 28027,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-IM-15070',
        'customer_name': 'Irene Maddox',
        'segment': 'Consumer',
        'age': 66,
        'country': 'United States',
        'city': 'Seattle',
        'state': 'Washington',
        'postal_code': 98103,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-HP-14815',
        'customer_name': 'Harold Pawlan',
        'segment': 'Home Office',
        'age': 20,
        'country': 'United States',
        'city': 'Fort Worth',
        'state': 'Texas',
        'postal_code': 76106,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-PK-19075',
        'customer_name': 'Pete Kriz',
        'segment': 'Consumer',
        'age': 46,
        'country': 'United States',
        'city': 'Madison',
        'state': 'Wisconsin',
        'postal_code': 53711,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-AG-10270',
        'customer_name': 'Alejandro Grove',
        'segment': 'Consumer',
        'age': 18,
        'country': 'United States',
        'city': 'West Jordan',
        'state': 'Utah',
        'postal_code': 84084,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-ZD-21925',
        'customer_name': 'Zuschuss Donatelli',
        'segment': 'Consumer',
        'age': 66,
        'country': 'United States',
        'city': 'San Francisco',
        'state': 'California',
        'postal_code': 94109,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-KB-16585',
        'customer_name': 'Ken Black',
        'segment': 'Corporate',
        'age': 67,
        'country': 'United States',
        'city': 'Fremont',
        'state': 'Nebraska',
        'postal_code': 68025,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-SF-20065',
        'customer_name': 'Sandra Flanagan',
        'segment': 'Consumer',
        'age': 41,
        'country': 'United States',
        'city': 'Philadelphia',
        'state': 'Pennsylvania',
        'postal_code': 19140,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-EB-13870',
        'customer_name': 'Emily Burns',
        'segment': 'Consumer',
        'age': 34,
        'country': 'United States',
        'city': 'Orem',
        'state': 'Utah',
        'postal_code': 84057,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-EH-13945',
        'customer_name': 'Eric Hoffmann',
        'segment': 'Consumer',
        'age': 21,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90049,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-TB-21520',
        'customer_name': 'Tracy Blumstein',
        'segment': 'Consumer',
        'age': 48,
        'country': 'United States',
        'city': 'Philadelphia',
        'state': 'Pennsylvania',
        'postal_code': 19140,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-MA-17560',
        'customer_name': 'Matt Abelman',
        'segment': 'Home Office',
        'age': 19,
        'country': 'United States',
        'city': 'Houston',
        'state': 'Texas',
        'postal_code': 77095,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-GH-14485',
        'customer_name': 'Gene Hale',
        'segment': 'Corporate',
        'age': 28,
        'country': 'United States',
        'city': 'Richardson',
        'state': 'Texas',
        'postal_code': 75080,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-SN-20710',
        'customer_name': 'Steve Nguyen',
        'segment': 'Home Office',
        'age': 46,
        'country': 'United States',
        'city': 'Houston',
        'state': 'Texas',
        'postal_code': 77041,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-LC-16930',
        'customer_name': 'Linda Cazamias',
        'segment': 'Corporate',
        'age': 31,
        'country': 'United States',
        'city': 'Naperville',
        'state': 'Illinois',
        'postal_code': 60540,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-RA-19885',
        'customer_name': 'Ruben Ausman',
        'segment': 'Corporate',
        'age': 51,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90049,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-ES-14080',
        'customer_name': 'Erin Smith',
        'segment': 'Corporate',
        'age': 20,
        'country': 'United States',
        'city': 'Melbourne',
        'state': 'Florida',
        'postal_code': 32935,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-ON-18715',
        'customer_name': 'Odella Nelson',
        'segment': 'Corporate',
        'age': 27,
        'country': 'United States',
        'city': 'Eagan',
        'state': 'Minnesota',
        'postal_code': 55122,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-PO-18865',
        'customer_name': 'Patrick O\'Donnell',
        'segment': 'Consumer',
        'age': 64,
        'country': 'United States',
        'city': 'Westland',
        'state': 'Michigan',
        'postal_code': 48185,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-LH-16900',
        'customer_name': 'Lena Hernandez',
        'segment': 'Consumer',
        'age': 66,
        'country': 'United States',
        'city': 'Dover',
        'state': 'Delaware',
        'postal_code': 19901,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-DP-13000',
        'customer_name': 'Darren Powers',
        'segment': 'Consumer',
        'age': 40,
        'country': 'United States',
        'city': 'New Albany',
        'state': 'Indiana',
        'postal_code': 47150,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-JM-15265',
        'customer_name': 'Janet Molinari',
        'segment': 'Corporate',
        'age': 23,
        'country': 'United States',
        'city': 'New York City',
        'state': 'New York',
        'postal_code': 10024,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-TB-21055',
        'customer_name': 'Ted Butterfield',
        'segment': 'Consumer',
        'age': 34,
        'country': 'United States',
        'city': 'Troy',
        'state': 'New York',
        'postal_code': 12180,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-KM-16720',
        'customer_name': 'Kunst Miller',
        'segment': 'Consumer',
        'age': 69,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90004,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-PS-18970',
        'customer_name': 'Paul Stevenson',
        'segment': 'Home Office',
        'age': 31,
        'country': 'United States',
        'city': 'Chicago',
        'state': 'Illinois',
        'postal_code': 60610,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-BS-11590',
        'customer_name': 'Brendan Sweed',
        'segment': 'Corporate',
        'age': 45,
        'country': 'United States',
        'city': 'Gilbert',
        'state': 'Arizona',
        'postal_code': 85234,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-KD-16270',
        'customer_name': 'Karen Daniels',
        'segment': 'Consumer',
        'age': 59,
        'country': 'United States',
        'city': 'Springfield',
        'state': 'Virginia',
        'postal_code': 22153,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-HM-14980',
        'customer_name': 'Henry MacAllister',
        'segment': 'Consumer',
        'age': 35,
        'country': 'United States',
        'city': 'New York City',
        'state': 'New York',
        'postal_code': 10009,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-JE-15745',
        'customer_name': 'Joel Eaton',
        'segment': 'Consumer',
        'age': 25,
        'country': 'United States',
        'city': 'Memphis',
        'state': 'Tennessee',
        'postal_code': 38109,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-KB-16600',
        'customer_name': 'Ken Brennan',
        'segment': 'Corporate',
        'age': 29,
        'country': 'United States',
        'city': 'Houston',
        'state': 'Texas',
        'postal_code': 77041,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-SC-20770',
        'customer_name': 'Stewart Carmichael',
        'segment': 'Corporate',
        'age': 18,
        'country': 'United States',
        'city': 'Decatur',
        'state': 'Alabama',
        'postal_code': 35601,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-DN-13690',
        'customer_name': 'Duane Noonan',
        'segment': 'Consumer',
        'age': 42,
        'country': 'United States',
        'city': 'San Francisco',
        'state': 'California',
        'postal_code': 94122,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-JC-16105',
        'customer_name': 'Julie Creighton',
        'segment': 'Corporate',
        'age': 56,
        'country': 'United States',
        'city': 'Durham',
        'state': 'North Carolina',
        'postal_code': 27707,
        'region': 'South'
    },
    {
        'cust_id': 'cust_id-CS-12400',
        'customer_name': 'Christopher Schild',
        'segment': 'Home Office',
        'age': 33,
        'country': 'United States',
        'city': 'Chicago',
        'state': 'Illinois',
        'postal_code': 60623,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-PG-18895',
        'customer_name': 'Paul Gonzalez',
        'segment': 'Consumer',
        'age': 64,
        'country': 'United States',
        'city': 'Rochester',
        'state': 'Minnesota',
        'postal_code': 55901,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-GM-14455',
        'customer_name': 'Gary Mitchum',
        'segment': 'Home Office',
        'age': 64,
        'country': 'United States',
        'city': 'Houston',
        'state': 'Texas',
        'postal_code': 77095,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-JS-15685',
        'customer_name': 'Jim Sink',
        'segment': 'Corporate',
        'age': 33,
        'country': 'United States',
        'city': 'Los Angeles',
        'state': 'California',
        'postal_code': 90036,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-KB-16315',
        'customer_name': 'Karl Braun',
        'segment': 'Consumer',
        'age': 70,
        'country': 'United States',
        'city': 'Minneapolis',
        'state': 'Minnesota',
        'postal_code': 55407,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-RB-19705',
        'customer_name': 'Roger Barcio',
        'segment': 'Home Office',
        'age': 63,
        'country': 'United States',
        'city': 'Portland',
        'state': 'Oregon',
        'postal_code': 97206,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-PN-18775',
        'customer_name': 'Parhena Norris',
        'segment': 'Home Office',
        'age': 35,
        'country': 'United States',
        'city': 'New York City',
        'state': 'New York',
        'postal_code': 10009,
        'region': 'East'
    },
    {
        'cust_id': 'cust_id-KD-16345',
        'customer_name': 'Katherine Ducich',
        'segment': 'Consumer',
        'age': 33,
        'country': 'United States',
        'city': 'San Francisco',
        'state': 'California',
        'postal_code': 94122,
        'region': 'West'
    },
    {
        'cust_id': 'cust_id-ER-13855',
        'customer_name': 'Elpida Rittenbach',
        'segment': 'Corporate',
        'age': 56,
        'country': 'United States',
        'city': 'Saint Paul',
        'state': 'Minnesota',
        'postal_code': 55106,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-RB-19465',
        'customer_name': 'Rick Bensley',
        'segment': 'Home Office',
        'age': 18,
        'country': 'United States',
        'city': 'Chicago',
        'state': 'Illinois',
        'postal_code': 60610,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-GZ-14470',
        'customer_name': 'Gary Zandusky',
        'segment': 'Consumer',
        'age': 64,
        'country': 'United States',
        'city': 'Rochester',
        'state': 'Minnesota',
        'postal_code': 55901,
        'region': 'Central'
    },
    {
        'cust_id': 'cust_id-LC-16870',
        'customer_name': 'Lena Cacioppo',
        'segment': 'Consumer',
        'age': 63,
        'country': 'United States',
        'city': 'Aurora',
        'state': 'Colorado',
        'postal_code': 80013,
        'region': 'West'
    },
    {
    'cust_id': 'cust_id-JM-15250',
    'customer_name': 'Janet Martin',
    'segment': 'Consumer',
    'age': 62,
    'country': 'United States',
    'city': 'Charlotte',
    'state': 'North Carolina',
    'postal_code': 28205,
    'region': 'South'
}

])

# %%
cust1
# Out:
#              cust_id       customer_name      segment  age        country  \
# 0   cust_id-CG-12520         Claire Gute     Consumer   67  United States
# 1   cust_id-DV-13045     Darrin Van Huff    Corporate   31  United States
# 2   cust_id-SO-20335      Sean O'Donnell     Consumer   65  United States
# 3   cust_id-BH-11710     Brosina Hoffman     Consumer   20  United States
# 4   cust_id-AA-10480        Andrew Allen     Consumer   50  United States
# 5   cust_id-IM-15070        Irene Maddox     Consumer   66  United States
# 6   cust_id-HP-14815       Harold Pawlan  Home Office   20  United States
# 7   cust_id-PK-19075           Pete Kriz     Consumer   46  United States
# 8   cust_id-AG-10270     Alejandro Grove     Consumer   18  United States
# 9   cust_id-ZD-21925  Zuschuss Donatelli     Consumer   66  United States
# 10  cust_id-KB-16585           Ken Black    Corporate   67  United States
# 11  cust_id-SF-20065     Sandra Flanagan     Consumer   41  United States
# ...

# %%
cust1.to_csv('cust.csv', index= 0)

# %%
sales = pd.DataFrame([{
            

    
        'order_line': 1,
        'order_id': 'CA-2016-152156',
        'order_date': '11/8/2016',
        'ship_date': '11/11/2016',
        'ship_mode': 'Second Class',
        'customer_id': 'CG-12520',
        'product_id': 'FUR-BO-10001798',
        'sales': 261.96,
        'quantity': 2,
        'discount': 0,
        'profit': 41.9136
    },
    {
        'order_line': 2,
        'order_id': 'CA-2016-152156',
        'order_date': '11/8/2016',
        'ship_date': '11/11/2016',
        'ship_mode': 'Second Class',
        'customer_id': 'CG-12520',
        'product_id': 'FUR-CH-10000454',
        'sales': 731.94,
        'quantity': 3,
        'discount': 0,
        'profit': 219.582
    },
    {
        'order_line': 3,
        'order_id': 'CA-2016-138688',
        'order_date': '6/12/2016',
        'ship_date': '6/16/2016',
        'ship_mode': 'Second Class',
        'customer_id': 'DV-13045',
        'product_id': 'OFF-LA-10000240',
        'sales': 14.62,
        'quantity': 2,
        'discount': 0,
        'profit': 6.8714
    },
    {
        'order_line': 4,
        'order_id': 'US-2015-108966',
        'order_date': '10/11/2015',
        'ship_date': '10/18/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SO-20335',
        'product_id': 'FUR-TA-10000577',
        'sales': 957.5775,
        'quantity': 5,
        'discount': 0.45,
        'profit': -383.031
    },
    {
        'order_line': 5,
        'order_id': 'US-2015-108966',
        'order_date': '10/11/2015',
        'ship_date': '10/18/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SO-20335',
        'product_id': 'OFF-ST-10000760',
        'sales': 22.368,
        'quantity': 2,
        'discount': 0.2,
        'profit': 2.5164
    },
    {
        'order_line': 6,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'FUR-FU-10001487',
        'sales': 48.86,
        'quantity': 7,
        'discount': 0,
        'profit': 14.1694
    },
    {
        'order_line': 7,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'OFF-AR-10002833',
        'sales': 7.28,
        'quantity': 4,
        'discount': 0,
        'profit': 1.9656
    },
    {
        'order_line': 8,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'TEC-PH-10002275',
        'sales': 907.152,
        'quantity': 6,
        'discount': 0.2,
        'profit': 90.7152
    },
    {
        'order_line': 9,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'OFF-BI-10003910',
        'sales': 18.504,
        'quantity': 3,
        'discount': 0.2,
        'profit': 5.7825
    },
    {
        'order_line': 10,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'OFF-AP-10002892',
        'sales': 114.9,
        'quantity': 5,
        'discount': 0,
        'profit': 34.47
    },
    {
        'order_line': 11,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'FUR-TA-10001539',
        'sales': 1706.184,
        'quantity': 9,
        'discount': 0.2,
        'profit': 85.3092
    },
    {
        'order_line': 12,
        'order_id': 'CA-2014-115812',
        'order_date': '6/9/2014',
        'ship_date': '6/14/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'BH-11710',
        'product_id': 'TEC-PH-10002033',
        'sales': 911.424,
        'quantity': 4,
        'discount': 0.2,
        'profit': 68.3568
    },
    {
        'order_line': 13,
        'order_id': 'CA-2017-114412',
        'order_date': '4/15/2017',
        'ship_date': '4/20/2017',
        'ship_mode': 'Standard Class',
        'customer_id': 'AA-10480',
        'product_id': 'OFF-PA-10002365',
        'sales': 15.552,
        'quantity': 3,
        'discount': 0.2,
        'profit': 5.4432
    },
    {
        'order_line': 14,
        'order_id': 'CA-2016-161389',
        'order_date': '12/5/2016',
        'ship_date': '12/10/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'IM-15070',
        'product_id': 'OFF-BI-10003656',
        'sales': 407.976,
        'quantity': 3,
        'discount': 0.2,
        'profit': 132.5922
    },
    {
        'order_line': 15,
        'order_id': 'US-2015-118983',
        'order_date': '11/22/2015',
        'ship_date': '11/26/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'HP-14815',
        'product_id': 'OFF-AP-10002311',
        'sales': 68.81,
        'quantity': 5,
        'discount': 0.8,
        'profit': -123.858
    },
    {
        'order_line': 16,
        'order_id': 'US-2015-118983',
        'order_date': '11/22/2015',
        'ship_date': '11/26/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'HP-14815',
        'product_id': 'OFF-BI-10000756',
        'sales': 2.544,
        'quantity': 3,
        'discount': 0.8,
        'profit': -3.816
    },
    {
        'order_line': 17,
        'order_id': 'CA-2014-105893',
        'order_date': '11/11/2014',
        'ship_date': '11/18/2014',
        'ship_mode': 'Standard Class',
        'customer_id': 'PK-19075',
        'product_id': 'OFF-ST-10004186',
        'sales': 665.88,
        'quantity': 6,
        'discount': 0,
        'profit': 13.3176
    },
    {
        'order_line': 18,
        'order_id': 'CA-2014-167164',
        'order_date': '5/13/2014',
        'ship_date': '5/15/2014',
        'ship_mode': 'Second Class',
        'customer_id': 'AG-10270',
        'product_id': 'OFF-ST-10000107',
        'sales': 55.5,
        'quantity': 2,
        'discount': 0,
        'profit': 9.99
    },
    {
        'order_line': 19,
        'order_id': 'CA-2014-143336',
        'order_date': '8/27/2014',
        'ship_date': '9/1/2014',
        'ship_mode': 'Second Class',
        'customer_id': 'ZD-21925',
        'product_id': 'OFF-AR-10003056',
        'sales': 8.56,
        'quantity': 2,
        'discount': 0,
        'profit': 2.4824
    },
    {
        'order_line': 20,
        'order_id': 'CA-2014-143336',
        'order_date': '8/27/2014',
        'ship_date': '9/1/2014',
        'ship_mode': 'Second Class',
        'customer_id': 'ZD-21925',
        'product_id': 'TEC-PH-10001949',
        'sales': 213.48,
        'quantity': 3,
        'discount': 0.2,
        'profit': 16.011
    },
    {
        'order_line': 21,
        'order_id': 'CA-2014-143336',
        'order_date': '8/27/2014',
        'ship_date': '9/1/2014',
        'ship_mode': 'Second Class',
        'customer_id': 'ZD-21925',
        'product_id': 'OFF-BI-10002215',
        'sales': 22.72,
        'quantity': 4,
        'discount': 0.2,
        'profit': 7.384
    },
    {
        'order_line': 22,
        'order_id': 'CA-2016-137330',
        'order_date': '12/9/2016',
        'ship_date': '12/13/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'KB-16585',
        'product_id': 'OFF-AR-10000246',
        'sales': 19.46,
        'quantity': 7,
        'discount': 0,
        'profit': 5.0596
    },
    {
        'order_line': 23,
        'order_id': 'CA-2016-137330',
        'order_date': '12/9/2016',
        'ship_date': '12/13/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'KB-16585',
        'product_id': 'OFF-AP-10001492',
        'sales': 60.34,
        'quantity': 7,
        'discount': 0,
        'profit': 15.6884
    },
    {
        'order_line': 24,
        'order_id': 'US-2017-156909',
        'order_date': '7/16/2017',
        'ship_date': '7/18/2017',
        'ship_mode': 'Second Class',
        'customer_id': 'SF-20065',
        'product_id': 'FUR-CH-10002774',
        'sales': 71.372,
        'quantity': 2,
        'discount': 0.3,
        'profit': -1.0196
    },
    {
        'order_line': 25,
        'order_id': 'CA-2015-106320',
        'order_date': '9/25/2015',
        'ship_date': '9/30/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'EB-13870',
        'product_id': 'FUR-TA-10000577',
        'sales': 1044.63,
        'quantity': 3,
        'discount': 0,
        'profit': 240.2649
    },
    {
        'order_line': 26,
        'order_id': 'CA-2016-121755',
        'order_date': '1/16/2016',
        'ship_date': '1/20/2016',
        'ship_mode': 'Second Class',
        'customer_id': 'EH-13945',
        'product_id': 'OFF-BI-10001634',
        'sales': 11.648,
        'quantity': 2,
        'discount': 0.2,
        'profit': 4.2224
    },
    {
        'order_line': 27,
        'order_id': 'CA-2016-121755',
        'order_date': '1/16/2016',
        'ship_date': '1/20/2016',
        'ship_mode': 'Second Class',
        'customer_id': 'EH-13945',
        'product_id': 'TEC-AC-10003027',
        'sales': 90.57,
        'quantity': 3,
        'discount': 0,
        'profit': 11.7741
    },
    {
        'order_line': 28,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'FUR-BO-10004834',
        'sales': 3083.43,
        'quantity': 7,
        'discount': 0.5,
        'profit': -1665.0522
    },
    {
        'order_line': 29,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'OFF-BI-10000474',
        'sales': 9.618,
        'quantity': 2,
        'discount': 0.7,
        'profit': -7.0532
    },
    {
        'order_line': 30,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'FUR-FU-10004848',
        'sales': 124.2,
        'quantity': 3,
        'discount': 0.2,
        'profit': 15.525
    },
    {
        'order_line': 31,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'OFF-EN-10001509',
        'sales': 3.264,
        'quantity': 2,
        'discount': 0.2,
        'profit': 1.1016
    },
    {
        'order_line': 32,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'OFF-AR-10004042',
        'sales': 86.304,
        'quantity': 6,
        'discount': 0.2,
        'profit': 9.7092
    },
    {
        'order_line': 33,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'OFF-BI-10001525',
        'sales': 6.858,
        'quantity': 6,
        'discount': 0.7,
        'profit': -5.715
    },
    {
        'order_line': 34,
        'order_id': 'US-2015-150630',
        'order_date': '9/17/2015',
        'ship_date': '9/21/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'TB-21520',
        'product_id': 'OFF-AR-10001683',
        'sales': 15.76,
        'quantity': 2,
        'discount': 0.2,
        'profit': 3.546
    },
    {
        'order_line': 35,
        'order_id': 'CA-2017-107727',
        'order_date': '10/19/2017',
        'ship_date': '10/23/2017',
        'ship_mode': 'Second Class',
        'customer_id': 'MA-17560',
        'product_id': 'OFF-PA-10000249',
        'sales': 29.472,
        'quantity': 3,
        'discount': 0.2,
        'profit': 9.9468
    },
    {
        'order_line': 36,
        'order_id': 'CA-2016-117590',
        'order_date': '12/8/2016',
        'ship_date': '12/10/2016',
        'ship_mode': 'First Class',
        'customer_id': 'GH-14485',
        'product_id': 'TEC-PH-10004977',
        'sales': 1097.544,
        'quantity': 7,
        'discount': 0.2,
        'profit': 123.4737
    },
    {
        'order_line': 37,
        'order_id': 'CA-2016-117590',
        'order_date': '12/8/2016',
        'ship_date': '12/10/2016',
        'ship_mode': 'First Class',
        'customer_id': 'GH-14485',
        'product_id': 'FUR-FU-10003664',
        'sales': 190.92,
        'quantity': 5,
        'discount': 0.6,
        'profit': -147.963
    },
    {
        'order_line': 38,
        'order_id': 'CA-2015-117415',
        'order_date': '12/27/2015',
        'ship_date': '12/31/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SN-20710',
        'product_id': 'OFF-EN-10002986',
        'sales': 113.328,
        'quantity': 9,
        'discount': 0.2,
        'profit': 35.415
    },
    {
        'order_line': 39,
        'order_id': 'CA-2015-117415',
        'order_date': '12/27/2015',
        'ship_date': '12/31/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SN-20710',
        'product_id': 'FUR-BO-10002545',
        'sales': 532.3992,
        'quantity': 3,
        'discount': 0.32,
        'profit': -46.9764
    },
    {
        'order_line': 40,
        'order_id': 'CA-2015-117415',
        'order_date': '12/27/2015',
        'ship_date': '12/31/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SN-20710',
        'product_id': 'FUR-CH-10004218',
        'sales': 212.058,
        'quantity': 3,
        'discount': 0.3,
        'profit': -15.147
    },
    {
        'order_line': 41,
        'order_id': 'CA-2015-117415',
        'order_date': '12/27/2015',
        'ship_date': '12/31/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'SN-20710',
        'product_id': 'TEC-PH-10000486',
        'sales': 371.168,
        'quantity': 4,
        'discount': 0.2,
        'profit': 41.7564
    },
    {
        'order_line': 42,
        'order_id': 'CA-2017-120999',
        'order_date': '9/10/2017',
        'ship_date': '9/15/2017',
        'ship_mode': 'Standard Class',
        'customer_id': 'LC-16930',
        'product_id': 'TEC-PH-10004093',
        'sales': 147.168,
        'quantity': 4,
        'discount': 0.2,
        'profit': 16.5564
    },
    {
        'order_line': 43,
        'order_id': 'CA-2016-101343',
        'order_date': '7/17/2016',
        'ship_date': '7/22/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'RA-19885',
        'product_id': 'OFF-ST-10003479',
        'sales': 77.88,
        'quantity': 2,
        'discount': 0,
        'profit': 3.894
    },
    {
        'order_line': 44,
        'order_id': 'CA-2017-139619',
        'order_date': '9/19/2017',
        'ship_date': '9/23/2017',
        'ship_mode': 'Standard Class',
        'customer_id': 'ES-14080',
        'product_id': 'OFF-ST-10003282',
        'sales': 95.616,
        'quantity': 2,
        'discount': 0.2,
        'profit': 9.5616
    },
    {
        'order_line': 45,
        'order_id': 'CA-2016-118255',
        'order_date': '3/11/2016',
        'ship_date': '3/13/2016',
        'ship_mode': 'First Class',
        'customer_id': 'ON-18715',
        'product_id': 'TEC-AC-10000171',
        'sales': 45.98,
        'quantity': 2,
        'discount': 0,
        'profit': 19.7714
    },
    {
        'order_line': 46,
        'order_id': 'CA-2016-118255',
        'order_date': '3/11/2016',
        'ship_date': '3/13/2016',
        'ship_mode': 'First Class',
        'customer_id': 'ON-18715',
        'product_id': 'OFF-BI-10003291',
        'sales': 17.46,
        'quantity': 2,
        'discount': 0,
        'profit': 8.2062
    },
    {
        'order_line': 47,
        'order_id': 'CA-2014-146703',
        'order_date': '10/20/2014',
        'ship_date': '10/25/2014',
        'ship_mode': 'Second Class',
        'customer_id': 'PO-18865',
        'product_id': 'OFF-ST-10001713',
        'sales': 211.96,
        'quantity': 4,
        'discount': 0,
        'profit': 8.4784
    },
    {
        'order_line': 48,
        'order_id': 'CA-2016-169194',
        'order_date': '6/20/2016',
        'ship_date': '6/25/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'LH-16900',
        'product_id': 'TEC-AC-10002167',
        'sales': 45,
        'quantity': 3,
        'discount': 0,
        'profit': 4.95
    },
    {
        'order_line': 49,
        'order_id': 'CA-2016-169194',
        'order_date': '6/20/2016',
        'ship_date': '6/25/2016',
        'ship_mode': 'Standard Class',
        'customer_id': 'LH-16900',
        'product_id': 'TEC-PH-10003988',
        'sales': 21.8,
        'quantity': 2,
        'discount': 0,
        'profit': 6.104
    },
    {
        'order_line': 50,
        'order_id': 'CA-2015-115742',
        'order_date': '4/18/2015',
        'ship_date': '4/22/2015',
        'ship_mode': 'Standard Class',
        'customer_id': 'DP-13000',
        'product_id': 'OFF-BI-10004410',
        'sales': 38.22,
        'quantity': 6,
        'discount': 0,
        'profit': 17.963
    

}])

# %%
sales
# Out:
#     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1            2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2            3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3            4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4            5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5            6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6            7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7            8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8            9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9           10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10          11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11          12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...

# %%
sales.to_csv('salesdata.csv', index= 0)

# %%
product = pd.DataFrame([
    {'product_id': 'FUR-BO-10001798','category': 'Furniture','sub_category': 'Bookcases','product_name': 'Bush Somerset Collection Bookcase'},
    {"product_id": "FUR-BO-10001798", "category": "Furniture","sub_category": "Bookcases","product_name": "Bush Somerset Collection Bookcase"},
    {"product_id": "FUR-CH-10000454", "category": "Furniture", "sub_category": "Chairs", "product_name": "Hon Deluxe Fabric Upholstered Stacking Chairs Rounded Back"},
    {"product_id": "OFF-LA-10000240", "category": "Office Supplies", "sub_category": "Labels", "product_name": "Self-Adhesive Address Labels for Typewriters by Universal"},
    {"product_id": "FUR-TA-10000577", "category": "Furniture", "sub_category": "Tables", "product_name": "Bretford CR4500 Series Slim Rectangular Table"},
    {"product_id": "OFF-ST-10000760", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Eldon Fold N Roll Cart System"},
    {"product_id": "FUR-FU-10001487", "category": "Furniture", "sub_category": "Furnishings", "product_name": "Eldon Expressions Wood and Plastic Desk Accessories Cherry Wood"},
    {"product_id": "OFF-AR-10002833", "category": "Office Supplies", "sub_category": "Art", "product_name": "Newell 322"},
    {"product_id": "TEC-PH-10002275", "category": "Technology", "sub_category": "Phones", "product_name": "Mitel 5320 IP Phone VoIP phone"},
    {"product_id": "OFF-BI-10003910", "category": "Office Supplies", "sub_category": "Binders", "product_name": "DXL Angle-View Binders with Locking Rings by Samsill"},
    {"product_id": "OFF-AP-10002892", "category": "Office Supplies", "sub_category": "Appliances", "product_name": "Belkin F5C206VTEL 6 Outlet Surge"},
    {"product_id": "FUR-TA-10001539", "category": "Furniture", "sub_category": "Tables", "product_name": "Chromcraft Rectangular Conference Tables"},
    {"product_id": "TEC-PH-10002033", "category": "Technology", "sub_category": "Phones", "product_name": "Konftel 250 Conference phone Charcoal black"},
    {"product_id": "OFF-PA-10002365", "category": "Office Supplies", "sub_category": "Paper", "product_name": "Xerox 1967"},
    {"product_id": "OFF-BI-10003656", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Fellowes PB200 Plastic Comb Binding Machine"},
    {"product_id": "OFF-AP-10002311", "category": "Office Supplies", "sub_category": "Appliances", "product_name": "Holmes Replacement Filter for HEPA Air Cleaner Very Large Room HEPA Filter"},
    {"product_id": "OFF-BI-10000756", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Storex DuraTech Recycled Plastic Frosted Binders"},
    {"product_id": "OFF-ST-10004186", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Stur-D-Stor Shelving Vertical 5-Shelf: 72H x 36W x 18 1/2D"},
    {"product_id": "OFF-ST-10000107", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Fellowes Super Stor/Drawer"},
    {"product_id": "OFF-AR-10003056", "category": "Office Supplies", "sub_category": "Art", "product_name": "Newell 341"},
    {"product_id": "TEC-PH-10001949", "category": "Technology", "sub_category": "Phones", "product_name": "Cisco SPA 501G IP Phone"},
    {"product_id": "OFF-BI-10002215", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Wilson Jones Hanging View Binder White 1"},
    {"product_id": "OFF-AR-10000246", "category": "Office Supplies", "sub_category": "Art", "product_name": "Newell 318"},
    {"product_id": "OFF-AP-10001492", "category": "Office Supplies", "sub_category": "Appliances", "product_name": "Acco Six-Outlet Power Strip 4 Cord Length"},
    {"product_id": "FUR-CH-10002774", "category": "Furniture", "sub_category": "Chairs", "product_name": "Global Deluxe Stacking Chair Gray"},
    {"product_id": "OFF-BI-10001634", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Wilson Jones Active Use Binders"},
    {"product_id": "TEC-AC-10003027", "category": "Technology", "sub_category": "Accessories", "product_name": "Imation 8GB Mini TravelDrive USB 2.0 Flash Drive"},
    {"product_id": "FUR-BO-10004834", "category": "Furniture", "sub_category": "Bookcases", "product_name": "Riverside Palais Royal Lawyers Bookcase Royale Cherry Finish"},
    {"product_id": "OFF-BI-10000474", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Avery Recycled Flexi-View Covers for Binding Systems"},
    {"product_id": "FUR-FU-10004848", "category": "Furniture", "sub_category": "Furnishings", "product_name": "Howard Miller 13-3/4 Diameter Brushed Chrome Round Wall Clock"},
    {"product_id": "OFF-EN-10001509", "category": "Office Supplies", "sub_category": "Envelopes", "product_name": "Poly String Tie Envelopes"},
    {"product_id": "OFF-AR-10004042", "category": "Office Supplies", "sub_category": "Art", "product_name": "BOSTON Model 1800 Electric Pencil Sharpeners Putty/Woodgrain"},
    {"product_id": "OFF-BI-10001525", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Acco Pressboard Covers with Storage Hooks 14 7/8 x 11 Executive Red"},
    {"product_id": "OFF-AR-10001683", "category": "Office Supplies", "sub_category": "Art", "product_name": "Lumber Crayons"},
    {"product_id": "OFF-PA-10000249", "category": "Office Supplies", "sub_category": "Paper", "product_name": "Easy-staple paper"},
    {"product_id": "TEC-PH-10004977", "category": "Technology", "sub_category": "Phones", "product_name": "GE 30524EE4"},
    {"product_id": "FUR-FU-10003664", "category": "Furniture", "sub_category": "Furnishings", "product_name": "Electrix Architects Clamp-On Swing Arm Lamp Black"},
    {"product_id": "OFF-EN-10002986", "category": "Office Supplies", "sub_category": "Envelopes", "product_name": "#10-4 1/8 x 9 1/2 Premium Diagonal Seam Envelopes"},
    {"product_id": "FUR-BO-10002545", "category": "Furniture", "sub_category": "Bookcases", "product_name": "Atlantic Metals Mobile 3-Shelf Bookcases Custom Colors"},
    {"product_id": "FUR-CH-10004218", "category": "Furniture", "sub_category": "Chairs", "product_name": "Global Fabric Managers Chair Dark Gray"},
    {"product_id": "TEC-PH-10000486", "category": "Technology", "sub_category": "Phones", "product_name": "Plantronics HL10 Handset Lifter"},
    {"product_id": "TEC-PH-10004093", "category": "Technology", "sub_category": "Phones", "product_name": "Panasonic Kx-TS550"},
    {"product_id": "OFF-ST-10003479", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Eldon Base for stackable storage shelf platinum"},
    {"product_id": "OFF-ST-10003282", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Advantus 10-Drawer Portable Organizer Chrome Metal Frame Smoke Drawers"},
    {"product_id": "TEC-AC-10000171", "category": "Technology", "sub_category": "Accessories", "product_name": "Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc 25/Pack"},
    {"product_id": "OFF-BI-10003291", "category": "Office Supplies", "sub_category": "Binders", "product_name": "Wilson Jones Leather-Like Binders with DublLock Round Rings"},
    {"product_id": "OFF-ST-10001713", "category": "Office Supplies", "sub_category": "Storage", "product_name": "Gould Plastics 9-Pocket Panel Bin 18-3/8w x 5-1/4d x 20-1/2h Black"},
    {"product_id": "TEC-AC-10002167", "category": "Technology", "sub_category": "Accessories", "product_name": "Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive"},
    {"product_id": "TEC-PH-10003988", "category": "Technology", "sub_category": "Phones", "product_name": "LF Elite 3D Dazzle Designer Hard Case Cover Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite"},
    {"product_id": "OFF-BI-10004410", "category": "Office Supplies", "sub_category": "Binders", "product_name": "C-Line Peel & Stick Add-On Filing Pockets 8-3/4 x 5-1/8 10/Pack"}


])

# %%
product
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-BO-10001798        Furniture    Bookcases
# 2   FUR-CH-10000454        Furniture       Chairs
# 3   OFF-LA-10000240  Office Supplies       Labels
# 4   FUR-TA-10000577        Furniture       Tables
# 5   OFF-ST-10000760  Office Supplies      Storage
# 6   FUR-FU-10001487        Furniture  Furnishings
# 7   OFF-AR-10002833  Office Supplies          Art
# 8   TEC-PH-10002275       Technology       Phones
# 9   OFF-BI-10003910  Office Supplies      Binders
# 10  OFF-AP-10002892  Office Supplies   Appliances
# 11  FUR-TA-10001539        Furniture       Tables
# 12  TEC-PH-10002033       Technology       Phones
# 13  OFF-PA-10002365  Office Supplies        Paper
# 14  OFF-BI-10003656  Office Supplies      Binders
# 15  OFF-AP-10002311  Office Supplies   Appliances
# 16  OFF-BI-10000756  Office Supplies      Binders
# 17  OFF-ST-10004186  Office Supplies      Storage
# ...

# %%
product.to_csv('product.csv', index= 0)
